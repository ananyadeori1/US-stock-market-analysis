# %%
import numpy as np
import pandas as pd

# %%
import yfinance as yf
import mplfinance as mpf

# %%
djia = yf.Ticker("DJIA").history('2y')

# %%
djia
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-05-20  25655.310547  25842.769531  25480.640625  25679.900391
# 2019-05-21  25782.339844  25995.669922  25660.289062  25877.330078
# 2019-05-22  25818.460938  25878.210938  25755.109375  25776.609375
# 2019-05-23  25657.990234  25657.990234  25328.089844  25490.470703
# 2019-05-24  25551.070312  25776.240234  25429.400391  25585.689453
# ...                  ...           ...           ...           ...
# 2021-05-13  33624.738281  34181.769531  33623.488281  34021.449219
# 2021-05-14  34050.859375  34454.050781  34050.859375  34382.128906
# 2021-05-17  34375.289062  34383.839844  34176.648438  34327.789062
# 2021-05-18  34351.179688  34408.988281  34044.101562  34060.660156
# 2021-05-19  33945.808594  33945.808594  33473.800781  33896.039062
#
#                 Volume  Dividends  Stock Splits
# Date
# 2019-05-20  3288870000          0             0
# 2019-05-21  3218700000          0             0
# 2019-05-22  3192510000          0             0
# 2019-05-23  3891980000          0             0
# 2019-05-24  2887390000          0             0
# ...                ...        ...           ...
# 2021-05-13  3687780000          0             0
# 2021-05-14  3251920000          0             0
# 2021-05-17  3307130000          0             0
# 2021-05-18  3559790000          0             0
# 2021-05-19  3485550000          0             0
#
# [505 rows x 7 columns]

# %%
mpf.plot(djia, savefig = 'img.png')

# %%
mpf.plot(djia['2020-1-1':'2020-04-30'])

# %%
djia.to_csv('djia.csv')
data=pd.read_csv('djia.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          505 non-null    object
#  1   Open          505 non-null    float64
#  2   High          505 non-null    float64
#  3   Low           505 non-null    float64
#  4   Close         505 non-null    float64
#  5   Volume        505 non-null    int64
#  6   Dividends     505 non-null    int64
#  7   Stock Splits  505 non-null    int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 31.7+ KB

# %%
data.Date=pd.to_datetime(data.Date)  #change 
data=data.set_index('Date')

# %%
mpf.plot(data)

# %%
mpf.plot(data['2020'])

# %%
mpf.plot(data['2020'], type='line')

# %%
mpf.plot(data['2020'], type='candle')

# %%
mpf.plot(data['2020'], type='renko')

# %%
mpf.plot(data, type='pnf')

# %%
mpf.plot(data['2020'], type='candle', volume=True)

# %%
mpf.plot(data['2020-02':'2020-06'], type='candle', 
         volume=True, mav=(20,5),title = 'DJIA 2020',
        tight_layout=True, figratio=(16,9) )

# %%
mpf.plot(data['2020-02':'2020-10'], type='candle', volume=True, mav=(20,5), style='yahoo')
