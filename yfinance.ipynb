# %%
import numpy as np
import pandas as pd

# %%
import yfinance as yf
import mplfinance as mpf

# %%
djia = yf.Ticker("DJIA").history('5y')

# %%
djia
# Out:
#                     Open          High           Low         Close  \
# Date
# 2016-05-20  17437.320312  17630.679688  17395.000000  17500.939453
# 2016-05-23  17507.039062  17610.169922  17410.609375  17492.929688
# 2016-05-24  17525.189453  17776.039062  17525.189453  17706.050781
# 2016-05-25  17735.089844  17946.970703  17714.369141  17851.509766
# 2016-05-26  17859.519531  17940.089844  17755.109375  17828.289062
# ...                  ...           ...           ...           ...
# 2021-05-13  33624.738281  34181.769531  33623.488281  34021.449219
# 2021-05-14  34050.859375  34454.050781  34050.859375  34382.128906
# 2021-05-17  34375.289062  34383.839844  34176.648438  34327.789062
# 2021-05-18  34351.179688  34408.988281  34044.101562  34060.660156
# 2021-05-19  33945.808594  33945.808594  33473.800781  33896.039062
#
#                 Volume  Dividends  Stock Splits
# Date
# 2016-05-20  3507650000          0             0
# 2016-05-23  3055480000          0             0
# 2016-05-24  3627340000          0             0
# 2016-05-25  3859160000          0             0
# 2016-05-26  3230990000          0             0
# ...                ...        ...           ...
# 2021-05-13  3687780000          0             0
# 2021-05-14  3251920000          0             0
# 2021-05-17  3307130000          0             0
# 2021-05-18  3559790000          0             0
# 2021-05-19  3485550000          0             0
#
# [1258 rows x 7 columns]

# %%
mpf.plot(djia, savefig = 'img.png')
# Out:
# C:\Users\91910\anaconda3\lib\site-packages\mplfinance\_arg_validators.py:35: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(djia['2021-01-01':'2021-03-01'])

# %%
djia.to_csv('djia.csv')
data=pd.read_csv('djia.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1258 non-null   object
#  1   Open          1258 non-null   float64
#  2   High          1258 non-null   float64
#  3   Low           1258 non-null   float64
#  4   Close         1258 non-null   float64
#  5   Volume        1258 non-null   int64
#  6   Dividends     1258 non-null   int64
#  7   Stock Splits  1258 non-null   int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 78.8+ KB

# %%
data.Date=pd.to_datetime(data.Date)  #change 
data=data.set_index('Date')

# %%
mpf.plot(data)
# Out:
# C:\Users\91910\anaconda3\lib\site-packages\mplfinance\_arg_validators.py:35: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(data['2021'])

# %%
mpf.plot(data['2020'], type='line')

# %%
mpf.plot(data['2021'], type='candle')

# %%
mpf.plot(data['2020'], type='renko')

# %%
mpf.plot(data, type='pnf')

# %%
mpf.plot(data['2021'], type='candle', volume=True)

# %%
mpf.plot(data['2020-07':'2020-12'], type='candle', 
         volume=True, mav=(20,5),title = 'DJIA 2020',
        tight_layout=True, figratio=(16,9) )

# %%
mpf.plot(data['2020-10':'2020-12'], type='candle', volume=True, mav=(20,5), style='yahoo')

# %%
mpf.available_styles()
# Out:
# ['binance',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'yahoo']
